# %% [markdown]
# <a href="https://colab.research.google.com/github/Mitei-DS/Matlplotlib/blob/main/Pandas_mitei.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np


#Define the datafram by importing csv file  it from PC
df=pd.read_csv('orders.csv')
print(df)
# Out:
#     OrderID      CustomerName                Product     Category  Quantity  \
# 0      1001        John Smith                 Laptop  Electronics         1
# 1      1002         Sarah Lee             Headphones  Electronics         2
# 2      1003          Ali Khan           Office Chair    Furniture         1
# 3      1004        Alice Wong              Desk Lamp    Furniture         3
# 4      1005     Carlos Mendez               Keyboard  Electronics         2
# 5      1006      Nora Ibrahim               Notebook   Stationery         5
# 6      1007       Emily Davis          Standing Desk    Furniture         1
# 7      1008        James Park                Monitor  Electronics         2
# 8      1009       Maria Rossi                    Pen   Stationery        10
# 9      1010  Takeshi Nakamura                  Mouse  Electronics         1
# 10     1011     Sophie Martin                 Webcam  Electronics         1
# ...

# %%
#check table headers
df.head()
# Out:
#    OrderID   CustomerName       Product     Category  Quantity   Price  \
# 0     1001     John Smith        Laptop  Electronics         1  1200.0
# 1     1002      Sarah Lee    Headphones  Electronics         2   150.0
# 2     1003       Ali Khan  Office Chair    Furniture         1   300.0
# 3     1004     Alice Wong     Desk Lamp    Furniture         3    45.0
# 4     1005  Carlos Mendez      Keyboard  Electronics         2    80.0
#
#     OrderDate Shipped    Country
# 0  2024-06-01     Yes        USA
# 1  2024-06-03      No     Canada
# 2  2024-06-04     Yes        UAE
# 3  2024-06-05     Yes  Singapore
# 4  2024-06-06      No     Mexico

# %%
#check the last five row
df.tail()
# Out:
#     OrderID    CustomerName             Product     Category  Quantity  Price  \
# 35     1036   Emma Thompson  Desk Lamp with USB    Furniture         1   68.0
# 36     1037   Carlos Santos    Wireless Earbuds  Electronics         1  125.0
# 37     1038  Leila Mansouri            Desk Pad    Furniture         1   28.0
# 38     1039      Daniel Kim         Power Strip  Electronics         2   18.0
# 39     1040    Anna Ivanova          Desk Clock    Furniture         1   35.0
#
#      OrderDate Shipped      Country
# 35  2024-07-07      No           UK
# 36  2024-07-08     Yes     Portugal
# 37  2024-07-09     Yes         Iran
# 38  2024-07-10      No  South Korea
# 39  2024-07-11     Yes      Ukraine

# %%
#get to know general information of the dataframe; this allows checking of missing values and headers as well as data types defined in each column
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   OrderID       40 non-null     int64
#  1   CustomerName  40 non-null     object
#  2   Product       40 non-null     object
#  3   Category      40 non-null     object
#  4   Quantity      40 non-null     int64
#  5   Price         40 non-null     float64
#  6   OrderDate     40 non-null     object
#  7   Shipped       40 non-null     object
#  8   Country       40 non-null     object
# dtypes: float64(1), int64(2), object(6)
# memory usage: 2.9+ KB

# %%
#Describing data by generating the descriptive statistics
df.describe()
# Out:
#            OrderID    Quantity        Price
# count    40.000000   40.000000    40.000000
# mean   1020.500000    5.450000   106.457500
# std      11.690452   15.903475   201.091854
# min    1001.000000    1.000000     0.800000
# 25%    1010.750000    1.000000    18.000000
# 50%    1020.500000    1.000000    43.500000
# 75%    1030.250000    2.250000   112.500000
# max    1040.000000  100.000000  1200.000000

# %%
#check the columns
df.columns
# Out:
# Index(['OrderID', 'CustomerName', 'Product', 'Category', 'Quantity', 'Price',
#        'OrderDate', 'Shipped', 'Country'],
#       dtype='object')

# %%
#check the indices
df.index
# Out:
# RangeIndex(start=0, stop=40, step=1)

# %%
#interactions with data i.e selecting columns of interest
#df['country'] will return series relating to column with countries
df["Country"]
# Out:
# 0              USA
# 1           Canada
# 2              UAE
# 3        Singapore
# 4           Mexico
# 5              UAE
# 6               UK
# 7      South Korea
# 8            Italy
# 9            Japan
# 10          France
# 11           India
# 12       Australia
# 13           Spain
# 14           China
# 15           Egypt
# 16          Poland
# 17             USA
# 18           Japan
# 19    Saudi Arabia
# 20          Canada
# 21          Brazil
# 22         Germany
# 23        Pakistan
# 24          Sweden
# 25          France
# 26       Argentina
# 27          Russia
# 28     South Korea
# 29           Italy
# 30         Morocco
# 31         Germany
# 32        Colombia
# 33             USA
# 34           Japan
# 35              UK
# 36        Portugal
# 37            Iran
# 38     South Korea
# 39         Ukraine
# Name: Country, dtype: object

# %%
#To get the size/number of data in a column we use len(df['country']) will return number of countries, where len is lenght.

len(df["Country"])
# Out:
# 40

# %%
#interactions with data i.e selecting columns of interest
#adding new column will be; df[["Country","product"]] will return series relating to column with countries and the products
# NOTE; the double square brackets because this is series with two columns

df[["Country", "Product"]]
# Out:
#          Country                Product
# 0            USA                 Laptop
# 1         Canada             Headphones
# 2            UAE           Office Chair
# 3      Singapore              Desk Lamp
# 4         Mexico               Keyboard
# 5            UAE               Notebook
# 6             UK          Standing Desk
# 7    South Korea                Monitor
# 8          Italy                    Pen
# 9          Japan                  Mouse
# 10        France                 Webcam
# 11         India           File Cabinet
# 12     Australia                Stapler
# 13         Spain              USB Drive
# 14         China              Bookshelf
# 15         Egypt          Printer Paper
# 16        Poland         Wireless Mouse
# 17           USA         Desk Organizer
# 18         Japan             Calculator
# 19  Saudi Arabia             Whiteboard
# 20        Canada           Highlighters
# 21        Brazil      Bluetooth Speaker
# ...

# %%
#interactions with data i.e selecting columns of interest
#Indexing also can be done based on the row, where we can get data relating to a single row
#We use iloc=stands for index Location
#use square bracket
df.iloc[0]
# Out:
# OrderID                1001
# CustomerName     John Smith
# Product              Laptop
# Category        Electronics
# Quantity                  1
# Price                1200.0
# OrderDate        2024-06-01
# Shipped                 Yes
# Country                 USA
# Name: 0, dtype: object

# %%
#interactions with data i.e selecting columns of interest
#Indexing also can be done based on the row, where we can get data relating to a single row
#We use iloc=stands for index Location
#use square brackets
#to get specific value of interest we reference deeper i.e to get the country specifically in row one
#Learn Pandas in 30 Minutes - Python Pandas Tutorial with tim

df.iloc[0][2]  #or get the product directly typying "Product"
# Out:
# /tmp/ipython-input-1000513467.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df.iloc[0][2]  #or get the product directly typying "Product"
# 'Laptop'

# %%
#get the product directly typying "Product"
df.iloc[0]["Product"]
# Out:
# 'Laptop'
